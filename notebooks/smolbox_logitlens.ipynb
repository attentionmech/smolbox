# %% [markdown]
# <a href="https://colab.research.google.com/github/attentionmech/smolbox/blob/main/notebooks/smolbox_logitlens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install uv
# !uv run --prerelease allow --with git+https://github.com/attentionmech/smolbox smolbox inspect/logitlens --model-name gpt2 --max-tokens 30
# Out:
# --------------------
# >> Executing tool: uv run --prerelease allow /root/.cache/uv/archive-v0/OGK_E0tRG-EA6u9K0GxAb/lib/python3.11/site-packages/smolbox/tools/inspect/logitlens.py run --model-name gpt2 --max-tokens 30
# --------------------
# Loading model...
# Model loaded successfully!
# Starting generation with initial prompt: 'The meaning of life is'
# Generating step 1/30...
# Computing logit lens for prompt: 'The meaning of life is'
# Detected GPT-style model.
# Generated token: ' a'
# Generating step 2/30...
# Computing logit lens for prompt: 'The meaning of life is a'
# Detected GPT-style model.
# Generated token: ' moment'
# Generating step 3/30...
# Computing logit lens for prompt: 'The meaning of life is a moment'
# Detected GPT-style model.
# Generated token: 'ary'
# Generating step 4/30...
# Computing logit lens for prompt: 'The meaning of life is a momentary'
# Detected GPT-style model.
# Generated token: ' thrill'
# Generating step 5/30...
# ...
